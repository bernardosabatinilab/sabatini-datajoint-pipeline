# %% [markdown]
# ### Sabatini Lab Pipeline Architechture Visualization

# %%
import datajoint as dj
import pandas as pd
from pathlib import Path
from datetime import datetime
import numpy as np
import warnings
import os
warnings.filterwarnings('ignore')

# %%
if os.path.basename(os.getcwd()) == "notebooks": 
    os.chdir("..")
dj.config.load('dj_local_conf.json')
dj.conn()
# Out:
# [2023-03-15 18:44:44,349][INFO]: Connecting rcadmin@sabatini-dj-prd01.cluster-cjvmzxer50q5.us-east-1.rds.amazonaws.com:3306
# [2023-03-15 18:44:44,995][INFO]: Connected rcadmin@sabatini-dj-prd01.cluster-cjvmzxer50q5.us-east-1.rds.amazonaws.com:3306
# DataJoint connection (connected) rcadmin@sabatini-dj-prd01.cluster-cjvmzxer50q5.us-east-1.rds.amazonaws.com:3306

# %%
from workflow import db_prefix
from workflow.pipeline import *

# %%
dj.list_schemas()
# Out:
#   Cell In[18], line 1
#     dj.list_schemas()?
#                      ^
# SyntaxError: invalid syntax

# %%
subject = dj.create_virtual_module('subject','sabatini_dj_subject')
session = dj.create_virtual_module('session','sabatini_dj_session')
trial = dj.create_virtual_module('trial','sabatini_dj_trial')
train = dj.create_virtual_module('train','sabatini_dj_train')
scan = dj.create_virtual_module('scan','sabatini_dj_scan')
ephys = dj.create_virtual_module('ephys','sabatini_dj_ephys')
event = dj.create_virtual_module('event','sabatini_dj_event')
imaging = dj.create_virtual_module('imaging','sabatini_dj_imaging')
photometry = dj.create_virtual_module('photometry', 'sabatini_dj_photometry')
model = dj.create_virtual_module('model','sabatini_dj_model')
reference = dj.create_virtual_module('reference','sabatini_dj_reference')
# ephys_support = dj.create_virtual_module('ephys_support','datajoint_support_neuropixels_ephys_support')
# ephys_sorter = dj.create_virtual_module('ephys_sorter','datajoint_neuropixels_ephys_sorter')
# admin_wf = dj.create_virtual_module('admin_wf','datajoint_admin_workflow')
# workerlog = dj.create_virtual_module('workerlog','datajoint_support_neuropixels_workerlog')

# %%
dj.Diagram(subject

# %%
dj.Diagram(session)

# %%
dj.Diagram(event)

# %%
dj.Diagram(trial)

# %%
dj.Diagram(ephys)

# %%
dj.Diagram(imaging)

# %%
dj.Diagram(photometry)

# %%
dj.Diagram(model)

# %%
dj.Diagram(reference)
